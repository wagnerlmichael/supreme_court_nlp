# %%
from convokit import Utterance, Corpus, Coordination, download

# Download the data
ROOT_DIR = download('supreme-2019', data_dir='C:/Users/Jonas/Desktop/UChicago/term_6/AdvancedMachineLearning/project')

# If already downloaded
# ROOT_DIR = '<YOUR DIRECTORY>'

corpus = Corpus(ROOT_DIR)

# %%
help(corpus)
# Out:
# Help on Corpus in module convokit.model.corpus object:
#
# class Corpus(builtins.object)
#  |  Corpus(filename: Optional[str] = None, utterances: Optional[List[convokit.model.utterance.Utterance]] = None, preload_vectors: List[str] = None, utterance_start_index: int = None, utterance_end_index: int = None, merge_lines: bool = False, exclude_utterance_meta: Optional[List[str]] = None, exclude_conversation_meta: Optional[List[str]] = None, exclude_speaker_meta: Optional[List[str]] = None, exclude_overall_meta: Optional[List[str]] = None, disable_type_check=True)
#  |
#  |  Represents a dataset, which can be loaded from a folder or constructed from a list of utterances.
#  |
#  |  :param filename: Path to a folder containing a Corpus or to an utterances.jsonl / utterances.json file to load
#  |  :param utterances: list of utterances to initialize Corpus from
#  |  :param preload_vectors: list of names of vectors to be preloaded from directory; by default,
# ...

# %%
corpus.get_conversation('24929')
# Out:
# Conversation({'obj_type': 'conversation', 'meta': {'case_id': '2019_18-877', 'advocates': {'derek_l_shaffer': {'side': 1, 'role': 'for the petitioners'}, 'ryan_park': {'side': 0, 'role': 'for the respondents'}}, 'win_side': 0, 'votes_side': {'j__john_g_roberts_jr': 0, 'j__clarence_thomas': 0, 'j__ruth_bader_ginsburg': 0, 'j__stephen_g_breyer': 0, 'j__samuel_a_alito_jr': 0, 'j__sonia_sotomayor': 0, 'j__elena_kagan': 0, 'j__neil_gorsuch': 0, 'j__brett_m_kavanaugh': 0}}, 'vectors': [], 'tree': None, 'owner': <convokit.model.corpus.Corpus object at 0x0000023B71B462C0>, 'id': '24929'})

# %%
corpus.get_speakers_dataframe()
# Out:
#                        vectors             meta.name meta.type meta.role
# id
# j__john_g_roberts_jr        []  John G. Roberts, Jr.         J   justice
# derek_l_shaffer             []      Derek L. Shaffer         A       NaN
# j__ruth_bader_ginsburg      []   Ruth Bader Ginsburg         J   justice
# j__elena_kagan              []           Elena Kagan         J   justice
# j__brett_m_kavanaugh        []    Brett M. Kavanaugh         J   justice
# ...                        ...                   ...       ...       ...
# jay_alan_sekulow            []      Jay Alan Sekulow         A       NaN
# carey_r_dunne               []        Carey R. Dunne         A       NaN
# david_w_bowker              []       David W. Bowker         A       NaN
# michael_k_kellogg           []    Michael K. Kellogg         A       NaN
# mark_c_fleming              []       Mark C. Fleming         A       NaN
#
# [113 rows x 4 columns]

# %%
corpus.get_utterance_ids()[1]
# Out:
# '24929__0_001'

# %%
corpus.get_utterance('24929__0_001')
# Out:
# Utterance({'obj_type': 'utterance', 'meta': {'case_id': '2019_18-877', 'start_times': [6.84, 18.52, 49.56, 57.96, 74.16, 78.68, 92.84, 108.0, 123.04, 134.68], 'stop_times': [18.52, 49.56, 57.96, 74.16, 78.68, 92.84, 108.0, 123.04, 134.68, 137.96], 'speaker_type': 'A', 'side': 1, 'timestamp': 6.84}, 'vectors': [], 'speaker': Speaker({'obj_type': 'speaker', 'meta': {'name': 'Derek L. Shaffer', 'type': 'A'}, 'vectors': [], 'owner': <convokit.model.corpus.Corpus object at 0x0000023B71B462C0>, 'id': 'derek_l_shaffer'}), 'conversation_id': '24929', 'reply_to': '24929__0_000', 'timestamp': None, 'text': "Mr. Chief Justice, and may it please the Court: When states infringe the exclusive federal rights that Congress is charged with securing, Congress can make states pay for doing so.\nThat's our respectful submission today, one that follows from the Constitution's text and affords ample basis for this Court to uphold the work Congress did in enacting the CRCA. Article I, Section 8, clause 8, 
# ...
