# %%
import os
import json
import pandas as pd

# %%
def flatten_case_info(input_file):
    '''
    Flattens json from https://convokit.cornell.edu/documentation/supreme.html

    Note: use only with case information json

    Input: case information json file

    Returns: Flattened dictionary
    '''
    max_num_advocates = 0
    advocate_info_to_keep = ['id', 'side']
    single_issues_to_keep = ['id', 'year', 'title', 'petitioner', 'respondent', 'adv_sides_inferred', 'known_respondent_adv', 'win_side', 'is_eq_divided']
    output = []
    with open(str(input_file), 'r') as f:
        for case_info in f:
            case_info = json.loads(case_info) # Make sure to load the line in as a dict not a str
            output_d = {}
            for k, v in case_info.items():
                if not isinstance(v, dict) and not isinstance(v, list):
                    if k in single_issues_to_keep:
                        output_d[k] = v
                elif k == "transcripts":
                    continue # Don't need
                elif k == "advocates":
                    j = 1
                    for person_info in v.values():  # Ignore actual name of attorney (key)
                        for key, identifier in person_info.items():
                            if key in advocate_info_to_keep:
                                long_key = k + "_" + str(j) + "_" + key
                                output_d[long_key] = identifier
                        max_num_advocates = max(max_num_advocates, j)
                        j += 1
                elif k == 'votes_side': # Let us know with petitioner only
                    for judge, vote in v.items():
                        long_key = k + "_" + judge
                        output_d[long_key] = vote
            output.append(output_d)
    return output

# %%
def count_columns(df_cols, prefix, divisor=1):
    '''
    Get count of substrings occuring in columns. Helpful in getting alphabetical cols

    Inputs:
        df_cols (list of str): col names to check
        prefix (str): prefix to check col names for
    
    Returns:
        cnt (int)
    '''
    cnt = 0
    for col in df_cols:
        if col.startswith(prefix):
            cnt += 1
    return cnt // divisor

# %%
def filter_columns(df_cols, prefix):
    '''
    Used to filter a list for substrings. Helpful in getting alphabetical cols

    Inputs:
        df_cols (list of str): col names to check
        prefix (str): prefix to check col names for
    
    Returns:
        cols (list)
    '''
    cols = []
    for col in df_cols:
        if col.startswith(prefix):
            cols.append(col)
    return sorted(cols)

# %%
curr_path = os.getcwd()
input_file = curr_path + "\cases.jsonl"
print(input_file, type(input_file))
# Out:
# c:\Users\matth\OneDrive\Documents\Harris\2nd_year\3rd_quarter\Machine_Learning_(NLP)\final_project\supreme_court_nlp\case_info_parsing\cases.jsonl <class 'str'>

# %%
list_of_dict = flatten_case_info(input_file)
df = pd.DataFrame(list_of_dict)
df
# Out:
#                 id  year                                              title  \
# 0          1955_71  1955                          Affronti v. United States
# 1         1955_410  1955  American Airlines, Inc. v. North American Airl...
# 2         1955_351  1955                               Archawski v. Hanioti
# 3          1955_38  1955                             Armstrong v. Armstrong
# 4          1955_49  1955  Bernhardt v. Polygraphic Company of America, Inc.
# ...            ...   ...                                                ...
# 7743    2019_19-46  2019  U.S. Patent and Trademark Office v. Booking.co...
# 7744   2019_19-177  2019  United States Agency for International Develop...
# 7745  2019_18-1584  2019  United States Forest Service v. Cowpasture Riv...
# 7746    2019_19-67  2019                    United States v. Sineneng-Smith
# 7747   2019_19-373  2019                            Walker v. United States
#
#                                              petitioner  \
# 0                                              Affronti
# 1                               American Airlines, Inc.
# 2                                             Archawski
# 3                                             Armstrong
# 4                                             Bernhardt
# ...                                                 ...
# 7743          United States Patent and Trademark Office
# 7744  United States Agency for International Develop...
# 7745               United States Forest Service, et al.
# 7746                           United States of America
# 7747                                       James Walker
#
#                                              respondent  adv_sides_inferred  \
# 0                                         United States                True
# 1                         North American Airlines, Inc.                True
# 2                                               Hanioti                True
# 3                                             Armstrong                True
# 4                  Polygraphic Company of America, Inc.                True
# ...                                                 ...                 ...
# 7743                                   Booking.com B.V.               False
# 7744  Alliance for Open Society International, Inc.,...               False
# 7745               Cowpasture River Association, et al.               False
# 7746                              Evelyn Sineneng-Smith               False
# 7747                           United States of America               False
#
#       known_respondent_adv        advocates_1_id  advocates_1_side  \
# 0                     True        harry_f_murphy               1.0
# 1                     True     howard_c_westwood               1.0
# 2                    False        harry_d_graham               3.0
# 3                    False       robert_n_gorman               3.0
# 4                    False   manfred_w_ehrich_jr               3.0
# ...                    ...                   ...               ...
# 7743                  True          erica_l_ross               1.0
# 7744                  True  christopher_g_michel               1.0
# 7745                  True        anthony_a_yang               1.0
# 7746                  True         eric_j_feigin               1.0
# 7747                 False                   NaN               NaN
#
#           advocates_2_id  ...  votes_side_j__david_h_souter  \
# 0         john_v_lindsay  ...                           NaN
# 1     walter_j_derenberg  ...                           NaN
# 2       israel_convisser  ...                           NaN
# 3       walter_k_sibbald  ...                           NaN
# 4      joseph_a_mcnamara  ...                           NaN
# ...                  ...  ...                           ...
# 7743        lisa_s_blatt  ...                           NaN
# 7744      david_w_bowker  ...                           NaN
# 7745      paul_d_clement  ...                           NaN
# 7746      mark_c_fleming  ...                           NaN
# 7747                 NaN  ...                           NaN
#
#       votes_side_j__clarence_thomas votes_side_j__ruth_bader_ginsburg  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
# ...                             ...                               ...
# 7743                            0.0                               0.0
# 7744                            1.0                               0.0
# 7745                            1.0                               1.0
# 7746                            1.0                               1.0
# 7747                            NaN                               NaN
#
#       votes_side_j__stephen_g_breyer  votes_side_j__john_g_roberts_jr  \
# 0                                NaN                              NaN
# 1                                NaN                              NaN
# 2                                NaN                              NaN
# 3                                NaN                              NaN
# 4                                NaN                              NaN
# ...                              ...                              ...
# 7743                             1.0                              0.0
# 7744                             0.0                              1.0
# 7745                             1.0                              1.0
# 7746                             1.0                              1.0
# 7747                             NaN                              NaN
#
#       votes_side_j__samuel_a_alito_jr  votes_side_j__sonia_sotomayor  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# ...                               ...                            ...
# 7743                              0.0                            0.0
# 7744                              1.0                            0.0
# 7745                              1.0                            0.0
# 7746                              1.0                            1.0
# 7747                              NaN                            NaN
#
#       votes_side_j__elena_kagan  votes_side_j__neil_gorsuch  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
# ...                         ...                         ...
# 7743                        0.0                         0.0
# 7744                        NaN                         1.0
# 7745                        0.0                         1.0
# 7746                        1.0                         1.0
# 7747                        NaN                         NaN
#
#       votes_side_j__brett_m_kavanaugh
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 7743                              0.0
# 7744                              1.0
# 7745                              1.0
# 7746                              1.0
# 7747                              NaN
#
# [7748 rows x 85 columns]

# %%
cols = df.columns
max_advocates = count_columns(cols, 'advocates_', 2) # have 2 columns associated with advocate (id, side)

# %%
advocate_subcols = ['id', 'side']
advocate_cols = []
for i in range(1, max_advocates + 1):
    for advocate_subcol in advocate_subcols:
        advocate_cols.append("advocates_" + str(i) + "_" + advocate_subcol)

# %%
init_cols = ['id', 'year', 'title', 'petitioner', 'respondent', 'adv_sides_inferred', 'known_respondent_adv', 'win_side', 'is_eq_divided'] # Get rid of win side_detail

votes_side = filter_columns(cols, "votes_side_j") # Some cases have no votes such as https://www.oyez.org/cases/1964/17-orig

cols_to_keep = init_cols + votes_side + advocate_cols

# %%
df = df[cols_to_keep]

# %%
df.to_csv('case_info_relevant_cols_only.csv', index=False)
