# %%
import os
import pandas as pd

os.chdir('C:\\Users\\Jonas\\Desktop\\UChicago\\term_6\\AdvancedMachineLearning\\supreme_court_nlp')

# %%
def get_judge_baseline(year_lb, year_ub):
    """
    Compute the baseline accuracy by judge for a given range of years

    Inputs:
        - lb_year (int): Lower bound year
        - ub_year (int): Upper bound year

    Outputs:
        - baslines (pd.DataFrame): Baselines by judge
    """
    # Load the data
    ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')

    # Count the number of cases vote by side
    vote_counts = ut.groupby(
        'case_id'
        ).first()[
        [
            col for col in ut.columns if col.startswith('votes_side_')
        ]
    ].apply(
        lambda vote: vote.value_counts(dropna=True)
    )
    display(vote_counts)

    # Compute the baseline
    baselines = pd.DataFrame(vote_counts.apply(
                lambda col: col.max() / col.sum(),
                axis=0
            ).dropna(),
            columns=['baseline']
    )

    baselines['baseline_side'] = vote_counts.apply(
        lambda col: col.idxmax(),
        axis=0
    ).dropna()
    
    return baselines[['baseline_side', 'baseline']]

# %%
def get_year_baseline(year_lb, year_ub):
    """
    Compute the baseline accuracy at the case level
    for a given range of years

    Inputs:
        - lb_year (int): Lower bound year
        - ub_year (int): Upper bound year

    Outputs:
        - win_side (int): win side of the baseline
        - baseline_side (pd.Series): Baseline
    """
    # Load the data
    counts = pd.read_csv(
        f'data/utterances_clean{year_lb}-{year_ub}.csv',
        usecols=['case_id', 'win_side']
    ).groupby(
        'case_id'
    ).first().value_counts()
    return int(counts.idxmax()[0]), counts.max() / counts.sum()

# %%
def get_all_judge_baselines():
    """
    get the judge baselines for all years

    Input:
        - None
    
    Output:
        - baselines (pd.DataFrame): baselines
            for the different judges across the
            years
    """
    year_bounds = [
        (1956, 1956),
        (1957, 1960),
        (1961, 1961),
        (1993, 1993),
        (1994, 1998),
        (1999, 1999),
        (2013, 2013),
        (2014, 2018),
        (2019, 2019)
    ]

    baselines = pd.DataFrame()
    for year_lb, year_ub in year_bounds:
        yr_baseline = get_judge_baseline(
                year_lb,
                year_ub
            )
        yr_baseline['justice'] = yr_baseline.index
        yr_baseline['justice'] = yr_baseline['justice'].apply(
            lambda name: name.strip('votes_side_')
        )
        yr_baseline['lb_year'], yr_baseline['ub_year'] = year_lb, year_ub
        baselines = pd.concat(
            [baselines, yr_baseline],
            axis=0
        ).reset_index(drop=True)
    baselines = baselines[['lb_year', 'ub_year', 'justice', 'baseline_side', 'baseline']]
    baselines.to_csv(f'eda/judge_baselines.csv', index=False)
    return baselines

get_all_judge_baselines()
# Out:
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
# -1.0                       NaN                              NaN
#  0.0                       NaN                              NaN
#  1.0                       NaN                              NaN
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
# -1.0                           NaN                              NaN
#  0.0                           NaN                              NaN
#  1.0                           NaN                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
# -1.0                              NaN                          NaN
#  0.0                              NaN                          NaN
#  1.0                              NaN                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
# -1.0                                NaN                            NaN
#  0.0                               18.0                            NaN
#  1.0                               21.0                            NaN
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
# -1.0                           NaN                          1  ...
#  0.0                           NaN                         35  ...
#  1.0                           NaN                         76  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
# -1.0                           NaN                            NaN
#  0.0                           1.0                            NaN
#  1.0                           NaN                            NaN
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
# -1.0                         NaN                             NaN
#  0.0                        24.0                             NaN
#  1.0                        17.0                             NaN
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
# -1.0                              NaN                          1
#  0.0                              NaN                         53
#  1.0                              NaN                         56
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
# -1.0                            NaN                                NaN
#  0.0                            NaN                                NaN
#  1.0                            NaN                                NaN
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
# -1.0                                   1                                1
#  0.0                                  36                               35
#  1.0                                  73                               78
#
# [3 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
# -1.0                       NaN                              NaN
#  0.0                       NaN                              NaN
#  1.0                       NaN                              NaN
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
# -1.0                           NaN                              NaN
#  0.0                           NaN                              NaN
#  1.0                           NaN                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
# -1.0                              NaN                          NaN
#  0.0                              NaN                          NaN
#  1.0                              NaN                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
# -1.0                                  8                            NaN
#  0.0                                239                            NaN
#  1.0                                233                            NaN
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
# -1.0                           NaN                          8  ...
#  0.0                           NaN                        151  ...
#  1.0                           NaN                        316  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
# -1.0                           NaN                            NaN
#  0.0                           NaN                            NaN
#  1.0                           NaN                            NaN
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
# -1.0                         NaN                             NaN
#  0.0                         NaN                             NaN
#  1.0                         NaN                             NaN
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
# -1.0                              NaN                          8
#  0.0                              NaN                        236
#  1.0                              NaN                        231
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
# -1.0                            NaN                                NaN
#  0.0                            NaN                                NaN
#  1.0                            NaN                                NaN
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
# -1.0                                   8                                8
#  0.0                                 148                              143
#  1.0                                 324                              329
#
# [3 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (60,62,64,66,68) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#      votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
# 0.0                       NaN                              NaN
# 1.0                       NaN                              NaN
#
#      votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
# 0.0                           NaN                                2
# 1.0                           NaN                                4
#
#      votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
# 0.0                              NaN                            5
# 1.0                              NaN                           13
#
#      votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
# 0.0                                 18                            NaN
# 1.0                                 16                            NaN
#
#      votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
# 0.0                           NaN                         22  ...
# 1.0                           NaN                         79  ...
#
#      votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
# 0.0                           NaN                            NaN
# 1.0                           NaN                            NaN
#
#      votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
# 0.0                         NaN                             NaN
# 1.0                         NaN                             NaN
#
#      votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
# 0.0                              NaN                         45
# 1.0                              NaN                         57
#
#      votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
# 0.0                            NaN                                NaN
# 1.0                            NaN                                NaN
#
#      votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
# 0.0                                  29                               24
# 1.0                                  73                               78
#
# [2 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (17,60,62,64,66,68,70) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
# -1.0                       NaN                                1
#  0.0                       NaN                               34
#  1.0                       NaN                               46
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
# -1.0                             1                              NaN
#  0.0                            39                              NaN
#  1.0                            41                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
# -1.0                              NaN                          NaN
#  0.0                              NaN                          NaN
#  1.0                              NaN                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
# -1.0                                NaN                              1
#  0.0                                NaN                             33
#  1.0                                NaN                             47
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
# -1.0                             1                        NaN  ...
#  0.0                            36                        NaN  ...
#  1.0                            44                        NaN  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
# -1.0                           NaN                            NaN
#  0.0                           NaN                            NaN
#  1.0                           NaN                            NaN
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
# -1.0                         NaN                             NaN
#  0.0                         NaN                             NaN
#  1.0                         NaN                             NaN
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
# -1.0                              NaN                        NaN
#  0.0                              NaN                        NaN
#  1.0                              NaN                        NaN
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
# -1.0                            NaN                                  1
#  0.0                            NaN                                 42
#  1.0                            NaN                                 38
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
# -1.0                                 NaN                              NaN
#  0.0                                 NaN                              NaN
#  1.0                                 NaN                              NaN
#
# [3 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (58,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
#  1.0                       NaN                              245
#  0.0                       NaN                              162
# -1.0                       NaN                                2
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
#  1.0                           233                              NaN
#  0.0                           173                              NaN
# -1.0                             2                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
#  1.0                              NaN                          NaN
#  0.0                              NaN                          NaN
# -1.0                              NaN                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
#  1.0                                NaN                            221
#  0.0                                NaN                            185
# -1.0                                NaN                              2
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
#  1.0                           235                        NaN  ...
#  0.0                           172                        NaN  ...
# -1.0                             2                        NaN  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
#  1.0                           NaN                            NaN
#  0.0                           NaN                            NaN
# -1.0                           NaN                            NaN
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
#  1.0                         NaN                             238
#  0.0                         NaN                             164
# -1.0                         NaN                               2
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
#  1.0                              NaN                        NaN
#  0.0                              NaN                        NaN
# -1.0                              NaN                        NaN
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
#  1.0                            NaN                                230
#  0.0                            NaN                                177
# -1.0                            NaN                                  2
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
#  1.0                                 NaN                              NaN
#  0.0                                 NaN                              NaN
# -1.0                                 NaN                              NaN
#
# [3 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (58) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
#  1.0                       NaN                               41
#  0.0                       NaN                               32
# -1.0                       NaN                                1
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
#  1.0                            43                              NaN
#  0.0                            30                              NaN
# -1.0                             1                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
#  1.0                              NaN                          NaN
#  0.0                              NaN                          NaN
# -1.0                              NaN                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
#  1.0                                NaN                             43
#  0.0                                NaN                             30
# -1.0                                NaN                              1
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
#  1.0                            43                        NaN  ...
#  0.0                            29                        NaN  ...
# -1.0                             1                        NaN  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
#  1.0                           NaN                            NaN
#  0.0                           NaN                            NaN
# -1.0                           NaN                            NaN
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
#  1.0                         NaN                              45
#  0.0                         NaN                              28
# -1.0                         NaN                               1
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
#  1.0                              NaN                        NaN
#  0.0                              NaN                        NaN
# -1.0                              NaN                        NaN
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
#  1.0                            NaN                                 44
#  0.0                            NaN                                 29
# -1.0                            NaN                                  1
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
#  1.0                                 NaN                              NaN
#  0.0                                 NaN                              NaN
# -1.0                                 NaN                              NaN
#
# [3 rows x 34 columns]
#      votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
# 1.0                       NaN                               43
# 0.0                       NaN                               23
#
#      votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
# 1.0                            43                              NaN
# 0.0                            23                              NaN
#
#      votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
# 1.0                              NaN                          NaN
# 0.0                              NaN                          NaN
#
#      votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
# 1.0                                NaN                             41
# 0.0                                NaN                             25
#
#      votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
# 1.0                           NaN                        NaN  ...
# 0.0                           NaN                        NaN  ...
#
#      votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
# 1.0                           NaN                             41
# 0.0                           NaN                             24
#
#      votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
# 1.0                         NaN                              40
# 0.0                         NaN                              25
#
#      votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
# 1.0                              NaN                        NaN
# 0.0                              NaN                        NaN
#
#      votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
# 1.0                            NaN                                NaN
# 0.0                            NaN                                NaN
#
#      votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
# 1.0                                 NaN                              NaN
# 0.0                                 NaN                              NaN
#
# [2 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (17,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
# -1.0                       NaN                                6
#  0.0                       NaN                               82
#  1.0                       NaN                              158
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
# -1.0                           NaN                              NaN
#  0.0                          23.0                              NaN
#  1.0                          43.0                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
# -1.0                              NaN                          NaN
#  0.0                             21.0                          NaN
#  1.0                             40.0                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
# -1.0                                NaN                              6
#  0.0                                NaN                            143
#  1.0                                NaN                            166
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
# -1.0                           NaN                        NaN  ...
#  0.0                           NaN                        NaN  ...
#  1.0                           NaN                        NaN  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
# -1.0                           NaN                              6
#  0.0                           NaN                            120
#  1.0                           NaN                            187
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
# -1.0                         NaN                               6
#  0.0                         NaN                             119
#  1.0                         NaN                             190
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
# -1.0                              NaN                        NaN
#  0.0                              NaN                        NaN
#  1.0                              NaN                        NaN
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
# -1.0                            NaN                                NaN
#  0.0                            NaN                                NaN
#  1.0                            NaN                                NaN
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
# -1.0                                 NaN                              NaN
#  0.0                                 NaN                              NaN
#  1.0                                 NaN                              NaN
#
# [3 rows x 34 columns]
# C:\Users\Jonas\AppData\Local\Temp\ipykernel_13920\87083862.py:13: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   ut = pd.read_csv(f'data/utterances_clean{year_lb}-{year_ub}.csv')
#       votes_side_j__abe_fortas  votes_side_j__anthony_m_kennedy  \
#  1.0                       NaN                              NaN
#  0.0                       NaN                              NaN
# -1.0                       NaN                              NaN
#
#       votes_side_j__antonin_scalia  votes_side_j__arthur_j_goldberg  \
#  1.0                           NaN                              NaN
#  0.0                           NaN                              NaN
# -1.0                           NaN                              NaN
#
#       votes_side_j__brett_m_kavanaugh  votes_side_j__byron_r_white  \
#  1.0                               32                          NaN
#  0.0                               22                          NaN
# -1.0                                2                          NaN
#
#       votes_side_j__charles_e_whittaker  votes_side_j__clarence_thomas  \
#  1.0                                NaN                             28
#  0.0                                NaN                             27
# -1.0                                NaN                              2
#
#       votes_side_j__david_h_souter  votes_side_j__earl_warren  ...  \
#  1.0                           NaN                        NaN  ...
#  0.0                           NaN                        NaN  ...
# -1.0                           NaN                        NaN  ...
#
#       votes_side_j__sherman_minton  votes_side_j__sonia_sotomayor  \
#  1.0                           NaN                             28
#  0.0                           NaN                             26
# -1.0                           NaN                              2
#
#       votes_side_j__stanley_reed  votes_side_j__stephen_g_breyer  \
#  1.0                         NaN                              38
#  0.0                         NaN                              17
# -1.0                         NaN                               2
#
#       votes_side_j__thurgood_marshall  votes_side_j__tom_c_clark  \
#  1.0                              NaN                        NaN
#  0.0                              NaN                        NaN
# -1.0                              NaN                        NaN
#
#       votes_side_j__warren_e_burger  votes_side_j__william_h_rehnquist  \
#  1.0                            NaN                                NaN
#  0.0                            NaN                                NaN
# -1.0                            NaN                                NaN
#
#       votes_side_j__william_j_brennan_jr  votes_side_j__william_o_douglas
#  1.0                                 NaN                              NaN
#  0.0                                 NaN                              NaN
# -1.0                                 NaN                              NaN
#
# [3 rows x 34 columns]
#     lb_year  ub_year                 justice  baseline_side  baseline
# 0      1956     1956  j__charles_e_whittaker            1.0  0.538462
# 1      1956     1956          j__earl_warren            1.0  0.678571
# 2      1956     1956    j__felix_frankfurter            1.0  0.530435
# 3      1956     1956        j__harold_burton            0.0  0.526316
# 4      1956     1956         j__hugo_l_black            1.0  0.672897
# ..      ...      ...                     ...            ...       ...
# 83     2019     2019         j__neil_gorsuch            1.0  0.543860
# 84     2019     2019  j__ruth_bader_ginsburg            1.0  0.631579
# 85     2019     2019    j__samuel_a_alito_jr            1.0  0.508772
# 86     2019     2019      j__sonia_sotomayor            1.0  0.500000
# 87     2019     2019     j__stephen_g_breyer            1.0  0.666667
#
# [88 rows x 5 columns]

# %%
def get_all_year_baselines():
    """
    get the judge baselines for all years

    Input:
        - None
    
    Output:
        - baselines (pd.DataFrame): baselines
            for the different judges across the
            years
    """
    year_bounds = [
        (1956, 1956),
        (1957, 1960),
        (1961, 1961),
        (1993, 1993),
        (1994, 1998),
        (1999, 1999),
        (2013, 2013),
        (2014, 2018),
        (2019, 2019)
    ]

    baselines = pd.DataFrame()
    for year_lb, year_ub in year_bounds:
        baseline_side, baseline = get_year_baseline(
            year_lb,
            year_ub
        )
        yr_baseline = pd.DataFrame(
                {
                    'lb_year': [year_lb],
                    'ub_year': [year_ub],
                    'baseline_side': [baseline_side],
                    'baseline': [baseline]
                }
            )
        baselines = pd.concat(
            [baselines, yr_baseline],
            axis=0
        ).reset_index(drop=True)
    baselines.to_csv(f'eda/year_baselines.csv', index=False)
    return baselines

get_all_year_baselines()
# Out:
#    lb_year  ub_year  baseline_side  baseline
# 0     1956     1956              1  0.626087
# 1     1957     1960              1  0.582988
# 2     1961     1961              1  0.705882
# 3     1993     1993              1  0.506173
# 4     1994     1998              1  0.601467
# 5     1999     1999              1  0.594595
# 6     2013     2013              1  0.681818
# 7     2014     2018              1  0.641270
# 8     2019     2019              1  0.596491
